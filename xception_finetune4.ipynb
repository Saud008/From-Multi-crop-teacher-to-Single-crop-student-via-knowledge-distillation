# %%
# Step 1 — Preprocess & Split (modified for new fine-tune plan)
import os, random, numpy as np
import tensorflow as tf
import cv2
from google.colab import drive
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (accuracy_score, f1_score, classification_report,
                             confusion_matrix, precision_recall_fscore_support,
                             cohen_kappa_score, roc_auc_score)
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.applications import Xception
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Reproducibility
SEED = 42
random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)

# Mount Google Drive
drive.mount('/content/drive')

# Paths
dataset_root = '/content/drive/MyDrive/PlantDoc-Dataset'
train_dir = f'{dataset_root}/train'
test_dir  = f'{dataset_root}/test'

# Loader
def load_plantdoc_data(data_dir, img_size=(299, 299)):
    X, y = [], []
    class_names = sorted([d for d in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, d))])
    class_to_idx = {cls_name: idx for idx, cls_name in enumerate(class_names)}
    for cls_name in class_names:
        cls_dir = os.path.join(data_dir, cls_name)
        for img_name in os.listdir(cls_dir):
            img_path = os.path.join(cls_dir, img_name)
            img = cv2.imread(img_path)
            if img is None:
                continue
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, img_size)
            X.append(img)
            y.append(class_to_idx[cls_name])
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.int32), class_names

# Load train/test
X_train, y_train, class_names = load_plantdoc_data(train_dir)
X_test,  y_test,  _           = load_plantdoc_data(test_dir)
num_classes = len(class_names)

# Normalize
X_train = X_train / 255.0
X_test  = X_test  / 255.0

# Split train → 80% train + 20% validation
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.2, stratify=y_train, random_state=SEED
)

# One-hot encode
y_train_cat = to_categorical(y_train, num_classes)
y_val_cat   = to_categorical(y_val, num_classes)
y_test_cat  = to_categorical(y_test, num_classes)

print(f"Train: {X_train.shape}, Val: {X_val.shape}, Test: {X_test.shape}")

# 🔹 NOTE for fine-tuning:
# - Later we will unfreeze *specific layers/blocks* of Xception (region-based training).
# - A callback will dynamically set `layer.trainable=True` after certain validation accuracy/epochs.
# - Post-training quantization (FP32/INT8) will be applied only on test dataset (Step 10).
# Out:
# Mounted at /content/drive
# Train: (1852, 299, 299, 3), Val: (464, 299, 299, 3), Test: (236, 299, 299, 3)

# %%
# Step 2 — Class Weights (handle imbalance, unchanged logic but aligned with fine-tune plan)
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(num_classes),
    y=y_train
)
class_weights = {i: w for i, w in enumerate(class_weights)}
print("Class Weights:", class_weights)

# 🔹 NOTE for fine-tuning:
# - These class weights will be applied during training.
# - Validation monitoring will be based on `val_accuracy` in later steps.
# Out:
# Class Weights: {0: np.float64(1.1063321385902032), 1: np.float64(1.0392817059483725), 2: np.float64(1.0887713109935333), 3: np.float64(1.6331569664902998), 4: np.float64(1.3718518518518519), 5: np.float64(0.8165784832451499), 6: np.float64(1.8050682261208577), 7: np.float64(1.3449527959331882), 8: np.float64(0.4763374485596708), 9: np.float64(0.8069716775599128), 10: np.float64(0.8364950316169828), 11: np.float64(0.7884206045125586), 12: np.float64(0.879392212725546), 13: np.float64(0.7884206045125586), 14: np.float64(1.4911433172302737), 15: np.float64(0.6999244142101285), 16: np.float64(0.9798941798941799), 17: np.float64(1.162586315128688), 18: np.float64(0.6292898402990146), 19: np.float64(1.595176571920758), 20: np.float64(0.879392212725546), 21: np.float64(0.846822130772748), 22: np.float64(1.9597883597883599), 23: np.float64(1.247138047138047), 24: np.float64(1.008714596949891), 25: np.float64(1.4911433172302737), 26: np.float64(1.5242798353909466)}

# %%
# Step 3 — Validation Monitoring (Kappa + Val Accuracy)
class KappaCallback(tf.keras.callbacks.Callback):
    def __init__(self, X_val, y_val_cat):
        super().__init__()
        self.X_val = X_val
        self.y_val_cat = y_val_cat

    def on_epoch_end(self, epoch, logs=None):
        # predictions
        y_val_pred = np.argmax(self.model.predict(self.X_val, verbose=0), axis=1)
        y_val_true = np.argmax(self.y_val_cat, axis=1)

        # compute kappa
        kappa = cohen_kappa_score(y_val_true, y_val_pred)

        # log both val_accuracy and kappa
        val_acc = logs.get("val_accuracy")
        print(f"\nEpoch {epoch+1} — Val Accuracy: {val_acc:.4f} — Val Cohen’s Kappa: {kappa:.4f}")

# %%
# Step 4 — Build Model (with augmentation & region-based fine-tuning)
def build_xception(num_classes, input_shape=(299, 299, 3), dropout=0.4, lr=1e-3,
                   label_smoothing=0.05, trainable_layers=0, trainable_region=None):
    """
    Args:
        num_classes: number of classes
        input_shape: input image shape
        dropout: dropout rate
        lr: learning rate
        label_smoothing: label smoothing factor
        trainable_layers: unfreeze last N layers (default)
        trainable_region: tuple (start_idx, end_idx) to unfreeze a region of base model
    """

    aug = tf.keras.Sequential([
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.1),
        layers.RandomContrast(0.1),
    ], name="augment")

    base = Xception(include_top=False, weights='imagenet', input_shape=input_shape)

    # Freeze everything first
    for layer in base.layers:
        layer.trainable = False

    # Option 1: Unfreeze last N layers
    if trainable_layers > 0:
        for layer in base.layers[-trainable_layers:]:
            layer.trainable = True

    # Option 2: Unfreeze specific region [start:end]
    if trainable_region is not None:
        start, end = trainable_region
        for layer in base.layers[start:end]:
            layer.trainable = True

    inputs = layers.Input(shape=input_shape)
    x = aug(inputs)
    x = base(x, training=False)   # base is partly frozen/unfrozen
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Dense(512, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs, outputs)

    loss = tf.keras.losses.CategoricalCrossentropy(label_smoothing=label_smoothing)
    model.compile(
        optimizer=optimizers.Adam(learning_rate=lr),
        loss=loss,
        metrics=['accuracy',
                 tf.keras.metrics.TopKCategoricalAccuracy(k=3, name='top3_acc'),
                 tf.keras.metrics.AUC(name='auc', multi_label=True)]
    )
    return model

# %%
# Step 5 — Warmup (train head, base frozen, monitoring val_accuracy)
warmup_epochs = 3
model = build_xception(
    num_classes=num_classes,
    lr=1e-3,
    dropout=0.4,
    label_smoothing=0.05,
    trainable_layers=0  # base frozen during warmup
)
model.summary()

chkpt_path = "/content/best_warmup.keras"
callbacks_warmup = [
    EarlyStopping(monitor='val_accuracy', patience=3, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_accuracy', patience=2, factor=0.3, min_lr=1e-7, mode='max'),
    ModelCheckpoint(chkpt_path, monitor='val_accuracy', mode='max', save_best_only=True, verbose=1),
    KappaCallback(X_val, y_val_cat)
]

history_warmup = model.fit(
    X_train, y_train_cat,
    validation_data=(X_val, y_val_cat),
    epochs=warmup_epochs,
    batch_size=32,
    class_weight=class_weights,
    callbacks=callbacks_warmup,
    verbose=1
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 299, 299, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ augment (Sequential)            │ (None, 299, 299, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception (Functional)           │ (None, 10, 10, 2048)   │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 27)             │        13,851 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,926,467 (83.64 MB)
#  Trainable params: 1,063,963 (4.06 MB)
#  Non-trainable params: 20,862,504 (79.58 MB)
# Epoch 1/3
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 17s/step - accuracy: 0.1618 - auc: 0.6898 - loss: 3.5224 - top3_acc: 0.3399
# Epoch 1: val_accuracy improved from -inf to 0.34914, saving model to /content/best_warmup.keras
#
# Epoch 1 — Val Accuracy: 0.3491 — Val Cohen’s Kappa: 0.3211
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1510s 26s/step - accuracy: 0.1629 - auc: 0.6912 - loss: 3.5157 - top3_acc: 0.3419 - val_accuracy: 0.3491 - val_auc: 0.9003 - val_loss: 2.3265 - val_top3_acc: 0.6530 - learning_rate: 0.0010
# Epoch 2/3
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 18s/step - accuracy: 0.4042 - auc: 0.8859 - loss: 2.2118 - top3_acc: 0.6807
# Epoch 2: val_accuracy improved from 0.34914 to 0.44397, saving model to /content/best_warmup.keras
#
# Epoch 2 — Val Accuracy: 0.4440 — Val Cohen’s Kappa: 0.4219
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1561s 27s/step - accuracy: 0.4041 - auc: 0.8860 - loss: 2.2127 - top3_acc: 0.6804 - val_accuracy: 0.4440 - val_auc: 0.9257 - val_loss: 2.0155 - val_top3_acc: 0.7328 - learning_rate: 0.0010
# Epoch 3/3
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 17s/step - accuracy: 0.4794 - auc: 0.9161 - loss: 1.9080 - top3_acc: 0.7400
# Epoch 3: val_accuracy improved from 0.44397 to 0.47414, saving model to /content/best_warmup.keras
#
# Epoch 3 — Val Accuracy: 0.4741 — Val Cohen’s Kappa: 0.4537
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1566s 26s/step - accuracy: 0.4793 - auc: 0.9163 - loss: 1.9084 - top3_acc: 0.7400 - val_accuracy: 0.4741 - val_auc: 0.9335 - val_loss: 1.8773 - val_top3_acc: 0.7522 - learning_rate: 0.0010

# %%
# Step 6 — Fine-tune (unfreeze last N layers, monitor val_accuracy)
N_UNFREEZE = 60  # specific region: last N layers

# Find base model inside current model
base = None
for lyr in model.layers:
    if isinstance(lyr, tf.keras.Model) and lyr.name.startswith('xception'):
        base = lyr; break
if base is None:
    base = model.layers[2]  # fallback

# Freeze all, unfreeze last N layers (specific region training)
for l in base.layers:
    l.trainable = False
for l in base.layers[-N_UNFREEZE:]:
    l.trainable = True

# Recompile with lower LR
model.compile(
    optimizer=optimizers.Adam(learning_rate=1e-4),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
    metrics=['accuracy',
             tf.keras.metrics.TopKCategoricalAccuracy(k=3, name='top3_acc'),
             tf.keras.metrics.AUC(name='auc', multi_label=True)]
)

chkpt_path_ft = "/content/drive/MyDrive/Xceptionfinetune3/best_finetune.keras"
callbacks_ft = [
    EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True),  # 🔹 monitor val_accuracy
    ReduceLROnPlateau(monitor='val_accuracy', patience=3, factor=0.3, min_lr=1e-7), # 🔹 monitor val_accuracy
    ModelCheckpoint(chkpt_path_ft, monitor='val_accuracy', save_best_only=True, verbose=1), # 🔹 monitor val_accuracy
    KappaCallback(X_val, y_val_cat)
]

history_ft = model.fit(
    X_train, y_train_cat,
    validation_data=(X_val, y_val_cat),
    epochs=20,
    batch_size=32,
    class_weight=class_weights,
    callbacks=callbacks_ft,
    verbose=1
)
# Out:
# Epoch 1/20
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 34s/step - accuracy: 0.4414 - auc: 0.9029 - loss: 2.0369 - top3_acc: 0.7019
# Epoch 1: val_accuracy improved from -inf to 0.51940, saving model to /content/drive/MyDrive/Xceptionfinetune3/best_finetune.keras
#
# Epoch 1 — Val Accuracy: 0.5194 — Val Cohen’s Kappa: 0.5001
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2514s 43s/step - accuracy: 0.4418 - auc: 0.9033 - loss: 2.0355 - top3_acc: 0.7024 - val_accuracy: 0.5194 - val_auc: 0.9493 - val_loss: 1.6952 - val_top3_acc: 0.7909 - learning_rate: 1.0000e-04
# Epoch 2/20
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 34s/step - accuracy: 0.6748 - auc: 0.9594 - loss: 1.3263 - top3_acc: 0.8869
# Epoch 2: val_accuracy improved from 0.51940 to 0.54526, saving model to /content/drive/MyDrive/Xceptionfinetune3/best_finetune.keras
#
# Epoch 2 — Val Accuracy: 0.5453 — Val Cohen’s Kappa: 0.5267
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2536s 43s/step - accuracy: 0.6743 - auc: 0.9596 - loss: 1.3272 - top3_acc: 0.8867 - val_accuracy: 0.5453 - val_auc: 0.9553 - val_loss: 1.5828 - val_top3_acc: 0.8211 - learning_rate: 1.0000e-04
# Epoch 3/20
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 34s/step - accuracy: 0.7374 - auc: 0.9696 - loss: 1.1215 - top3_acc: 0.9207
# Epoch 3: val_accuracy improved from 0.54526 to 0.58836, saving model to /content/drive/MyDrive/Xceptionfinetune3/best_finetune.keras
#
# Epoch 3 — Val Accuracy: 0.5884 — Val Cohen’s Kappa: 0.5709
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2515s 42s/step - accuracy: 0.7369 - auc: 0.9698 - loss: 1.1222 - top3_acc: 0.9206 - val_accuracy: 0.5884 - val_auc: 0.9589 - val_loss: 1.5127 - val_top3_acc: 0.8470 - learning_rate: 1.0000e-04
# Epoch 4/20
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 33s/step - accuracy: 0.7842 - auc: 0.9742 - loss: 1.0329 - top3_acc: 0.9343
# Epoch 4: val_accuracy did not improve from 0.58836
#
# Epoch 4 — Val Accuracy: 0.5754 — Val Cohen’s Kappa: 0.5578
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2482s 42s/step - accuracy: 0.7839 - auc: 0.9744 - loss: 1.0334 - top3_acc: 0.9343 - val_accuracy: 0.5754 - val_auc: 0.9598 - val_loss: 1.5194 - val_top3_acc: 0.8427 - learning_rate: 1.0000e-04
# Epoch 5/20
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 34s/step - accuracy: 0.8204 - auc: 0.9792 - loss: 0.9029 - top3_acc: 0.9571
# Epoch 5: val_accuracy did not improve from 0.58836
#
# Epoch 5 — Val Accuracy: 0.5819 — Val Cohen’s Kappa: 0.5642
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2469s 42s/step - accuracy: 0.8204 - auc: 0.9794 - loss: 0.9033 - top3_acc: 0.9570 - val_accuracy: 0.5819 - val_auc: 0.9587 - val_loss: 1.5173 - val_top3_acc: 0.8427 - learning_rate: 1.0000e-04
# Epoch 6/20
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 33s/step - accuracy: 0.8441 - auc: 0.9825 - loss: 0.8182 - top3_acc: 0.9762
# Epoch 6: val_accuracy did not improve from 0.58836
#
# Epoch 6 — Val Accuracy: 0.5797 — Val Cohen’s Kappa: 0.5622
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2503s 43s/step - accuracy: 0.8442 - auc: 0.9827 - loss: 0.8182 - top3_acc: 0.9762 - val_accuracy: 0.5797 - val_auc: 0.9581 - val_loss: 1.5417 - val_top3_acc: 0.8578 - learning_rate: 1.0000e-04
# Epoch 7/20
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 33s/step - accuracy: 0.8866 - auc: 0.9841 - loss: 0.7370 - top3_acc: 0.9842
# Epoch 7: val_accuracy improved from 0.58836 to 0.59483, saving model to /content/drive/MyDrive/Xceptionfinetune3/best_finetune.keras
#
# Epoch 7 — Val Accuracy: 0.5948 — Val Cohen’s Kappa: 0.5777
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2457s 43s/step - accuracy: 0.8865 - auc: 0.9843 - loss: 0.7374 - top3_acc: 0.9841 - val_accuracy: 0.5948 - val_auc: 0.9589 - val_loss: 1.5110 - val_top3_acc: 0.8578 - learning_rate: 3.0000e-05
# Epoch 8/20
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 33s/step - accuracy: 0.8979 - auc: 0.9850 - loss: 0.7169 - top3_acc: 0.9916
# Epoch 8: val_accuracy did not improve from 0.59483
#
# Epoch 8 — Val Accuracy: 0.5884 — Val Cohen’s Kappa: 0.5709
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2461s 42s/step - accuracy: 0.8979 - auc: 0.9852 - loss: 0.7173 - top3_acc: 0.9914 - val_accuracy: 0.5884 - val_auc: 0.9577 - val_loss: 1.5058 - val_top3_acc: 0.8621 - learning_rate: 3.0000e-05
# Epoch 9/20
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 33s/step - accuracy: 0.9018 - auc: 0.9849 - loss: 0.7182 - top3_acc: 0.9833
# Epoch 9: val_accuracy improved from 0.59483 to 0.60129, saving model to /content/drive/MyDrive/Xceptionfinetune3/best_finetune.keras
#
# Epoch 9 — Val Accuracy: 0.6013 — Val Cohen’s Kappa: 0.5844
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2413s 42s/step - accuracy: 0.9019 - auc: 0.9851 - loss: 0.7181 - top3_acc: 0.9834 - val_accuracy: 0.6013 - val_auc: 0.9574 - val_loss: 1.5003 - val_top3_acc: 0.8513 - learning_rate: 3.0000e-05
# Epoch 10/20
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 33s/step - accuracy: 0.9094 - auc: 0.9852 - loss: 0.6908 - top3_acc: 0.9874
# Epoch 10: val_accuracy did not improve from 0.60129
#
# Epoch 10 — Val Accuracy: 0.5970 — Val Cohen’s Kappa: 0.5799
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2431s 42s/step - accuracy: 0.9094 - auc: 0.9854 - loss: 0.6910 - top3_acc: 0.9874 - val_accuracy: 0.5970 - val_auc: 0.9565 - val_loss: 1.5057 - val_top3_acc: 0.8556 - learning_rate: 3.0000e-05
# Epoch 11/20
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 33s/step - accuracy: 0.9277 - auc: 0.9858 - loss: 0.6583 - top3_acc: 0.9925
# Epoch 11: val_accuracy improved from 0.60129 to 0.60560, saving model to /content/drive/MyDrive/Xceptionfinetune3/best_finetune.keras
#
# Epoch 11 — Val Accuracy: 0.6056 — Val Cohen’s Kappa: 0.5889
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2457s 42s/step - accuracy: 0.9276 - auc: 0.9861 - loss: 0.6585 - top3_acc: 0.9925 - val_accuracy: 0.6056 - val_auc: 0.9547 - val_loss: 1.4989 - val_top3_acc: 0.8534 - learning_rate: 3.0000e-05
# Epoch 12/20
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 33s/step - accuracy: 0.9313 - auc: 0.9860 - loss: 0.6453 - top3_acc: 0.9931
# Epoch 12: val_accuracy improved from 0.60560 to 0.60776, saving model to /content/drive/MyDrive/Xceptionfinetune3/best_finetune.keras
#
# Epoch 12 — Val Accuracy: 0.6078 — Val Cohen’s Kappa: 0.5911
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2427s 42s/step - accuracy: 0.9314 - auc: 0.9862 - loss: 0.6455 - top3_acc: 0.9930 - val_accuracy: 0.6078 - val_auc: 0.9572 - val_loss: 1.5048 - val_top3_acc: 0.8534 - learning_rate: 3.0000e-05
# Epoch 13/20
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 33s/step - accuracy: 0.9282 - auc: 0.9858 - loss: 0.6443 - top3_acc: 0.9914
# Epoch 13: val_accuracy did not improve from 0.60776
#
# Epoch 13 — Val Accuracy: 0.5927 — Val Cohen’s Kappa: 0.5754
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2445s 42s/step - accuracy: 0.9281 - auc: 0.9860 - loss: 0.6446 - top3_acc: 0.9914 - val_accuracy: 0.5927 - val_auc: 0.9556 - val_loss: 1.5118 - val_top3_acc: 0.8513 - learning_rate: 3.0000e-05
# Epoch 14/20
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 33s/step - accuracy: 0.9291 - auc: 0.9862 - loss: 0.6330 - top3_acc: 0.9971
# Epoch 14: val_accuracy improved from 0.60776 to 0.60991, saving model to /content/drive/MyDrive/Xceptionfinetune3/best_finetune.keras
#
# Epoch 14 — Val Accuracy: 0.6099 — Val Cohen’s Kappa: 0.5935
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2427s 42s/step - accuracy: 0.9291 - auc: 0.9864 - loss: 0.6329 - top3_acc: 0.9970 - val_accuracy: 0.6099 - val_auc: 0.9558 - val_loss: 1.5194 - val_top3_acc: 0.8556 - learning_rate: 3.0000e-05
# Epoch 15/20
# 15/58 ━━━━━━━━━━━━━━━━━━━━ 23:47 33s/step - accuracy: 0.9497 - auc: 0.9502 - loss: 0.5859 - top3_acc: 0.9990

# %%
from tensorflow import keras
model = keras.models.load_model("/content/drive/MyDrive/Xceptionfinetune3/best_finetune.keras")

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
    metrics=['accuracy',
             keras.metrics.TopKCategoricalAccuracy(k=3, name='top3_acc'),
             keras.metrics.AUC(name='auc', multi_label=True)]
)

# %%
from sklearn.metrics import cohen_kappa_score
from tensorflow.keras.callbacks import Callback
import numpy as np

class KappaCallback(Callback):
    def __init__(self, X_val, y_val):
        super().__init__()
        self.X_val = X_val
        self.y_val = y_val

    def on_epoch_end(self, epoch, logs=None):
        y_pred = self.model.predict(self.X_val, verbose=0)
        y_pred_classes = np.argmax(y_pred, axis=1)
        y_true_classes = np.argmax(self.y_val, axis=1)
        kappa = cohen_kappa_score(y_true_classes, y_pred_classes)
        print(f"Val Cohen's Kappa: {kappa:.4f}")
        logs["val_kappa"] = kappa

# %%
callbacks_ft = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', patience=3, factor=0.3, min_lr=1e-7),
    ModelCheckpoint("/content/drive/MyDrive/Xceptionfinetune3/best_finetune.keras",
                    monitor='val_loss', save_best_only=True, verbose=1),
    KappaCallback(X_val, y_val_cat)
]

# %%
import tensorflow as tf
import numpy as np
from sklearn.metrics import cohen_kappa_score
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# 🔹 1. Reload model from your last saved checkpoint
model = tf.keras.models.load_model("/content/drive/MyDrive/Xceptionfinetune3/best_finetune.keras")

# 🔹 2. Recreate KappaCallback
class KappaCallback(tf.keras.callbacks.Callback):
    def __init__(self, X_val, y_val_cat):
        super().__init__()
        self.X_val = X_val
        self.y_val_cat = y_val_cat

    def on_epoch_end(self, epoch, logs=None):
        y_val_pred = np.argmax(self.model.predict(self.X_val, verbose=0), axis=1)
        y_val_true = np.argmax(self.y_val_cat, axis=1)
        kappa = cohen_kappa_score(y_val_true, y_val_pred)
        print(f"\nEpoch {epoch+1} — Val Cohen’s Kappa: {kappa:.4f}")

# 🔹 3. (Re)define your class_weights again
# Example: if you had previously computed them
from sklearn.utils.class_weight import compute_class_weight
classes = np.unique(y_train)   # your training labels (int)
class_weights = compute_class_weight("balanced", classes=classes, y=y_train)
class_weights = dict(zip(classes, class_weights))

# 🔹 4. Unfreeze last N layers again (fine-tune)
N_UNFREEZE = 60
base = None
for lyr in model.layers:
    if isinstance(lyr, tf.keras.Model) and lyr.name.startswith('xception'):
        base = lyr; break
if base is None:
    base = model.layers[2]

for l in base.layers:
    l.trainable = False
for l in base.layers[-N_UNFREEZE:]:
    l.trainable = True

model.compile(
    optimizer=optimizers.Adam(learning_rate=1e-4),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
    metrics=['accuracy',
             tf.keras.metrics.TopKCategoricalAccuracy(k=3, name='top3_acc'),
             tf.keras.metrics.AUC(name='auc', multi_label=True)]
)

chkpt_path_ft = "/content/drive/MyDrive/Xceptionfinetune3/best_finetune.keras"
callbacks_ft = [
    EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_accuracy', patience=3, factor=0.3, min_lr=1e-7),
    ModelCheckpoint(chkpt_path_ft, monitor='val_accuracy', save_best_only=True, verbose=1),
    KappaCallback(X_val, y_val_cat)
]

# 🔹 5. Continue training
history_ft = model.fit(
    X_train, y_train_cat,
    validation_data=(X_val, y_val_cat),
    epochs=20,  # continue more epochs
    batch_size=32,
    class_weight=class_weights,
    callbacks=callbacks_ft,
    verbose=1
)
# Out:
# Epoch 1/20
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 31s/step - accuracy: 0.9199 - auc: 0.9858 - loss: 0.6583 - top3_acc: 0.9883
# Epoch 1: val_accuracy improved from -inf to 0.62500, saving model to /content/drive/MyDrive/Xceptionfinetune3/best_finetune.keras
#
# Epoch 1 — Val Cohen’s Kappa: 0.6087
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2326s 40s/step - accuracy: 0.9199 - auc: 0.9860 - loss: 0.6586 - top3_acc: 0.9883 - val_accuracy: 0.6250 - val_auc: 0.9494 - val_loss: 1.5673 - val_top3_acc: 0.8621 - learning_rate: 1.0000e-04
# Epoch 2/20
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 31s/step - accuracy: 0.9591 - auc: 0.9862 - loss: 0.6031 - top3_acc: 0.9940
# Epoch 2: val_accuracy did not improve from 0.62500
#
# Epoch 2 — Val Cohen’s Kappa: 0.6042
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2380s 40s/step - accuracy: 0.9589 - auc: 0.9864 - loss: 0.6032 - top3_acc: 0.9940 - val_accuracy: 0.6207 - val_auc: 0.9483 - val_loss: 1.5621 - val_top3_acc: 0.8578 - learning_rate: 1.0000e-04
# Epoch 3/20
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 31s/step - accuracy: 0.9549 - auc: 0.9863 - loss: 0.5747 - top3_acc: 0.9954
# Epoch 3: val_accuracy improved from 0.62500 to 0.63578, saving model to /content/drive/MyDrive/Xceptionfinetune3/best_finetune.keras
#
# Epoch 3 — Val Cohen’s Kappa: 0.6203
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2323s 40s/step - accuracy: 0.9548 - auc: 0.9865 - loss: 0.5752 - top3_acc: 0.9954 - val_accuracy: 0.6358 - val_auc: 0.9539 - val_loss: 1.5417 - val_top3_acc: 0.8578 - learning_rate: 1.0000e-04
# Epoch 4/20
# 20/58 ━━━━━━━━━━━━━━━━━━━━ 19:42 31s/step - accuracy: 0.9713 - auc: 0.9623 - loss: 0.5453 - top3_acc: 0.9961
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4151245095.py in <cell line: 0>()
#      59
#      60 # 🔹 5. Continue training
# ---> 61 history_ft = model.fit(
#      62     X_train, y_train_cat,
#      63     validation_data=(X_val, y_val_cat),
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     375                 for step, iterator in epoch_iterator:
#     376                     callbacks.on_train_batch_begin(step)
# --> 377                     logs = self.train_function(iterator)
#     378                     callbacks.on_train_batch_end(step, logs)
#     379                     if self.stop_training:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     218                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     219             ):
# --> 220                 opt_outputs = multi_step_on_iterator(iterator)
#     221                 if not opt_outputs.has_value():
#     222                     raise StopIteration
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1686     cancellation_context = cancellation.context()
#    1687     if cancellation_context is None:
# -> 1688       outputs = execute.execute(
#    1689           name.decode("utf-8"),
#    1690           num_outputs=num_outputs,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Step 7 — Evaluate
y_pred_proba = model.predict(X_test, verbose=0)
y_pred = y_pred_proba.argmax(axis=1)
y_true = y_test

acc = accuracy_score(y_true, y_pred)
f1w = f1_score(y_true, y_pred, average='weighted')

try:
    macro_auc = roc_auc_score(y_test_cat, y_pred_proba, multi_class='ovr', average='macro')
except ValueError:
    macro_auc = np.nan

kappa = cohen_kappa_score(y_true, y_pred)
report = classification_report(y_true, y_pred, target_names=class_names)

print(f"Test Accuracy: {acc:.4f}")
print(f"Test Weighted F1: {f1w:.4f}")
print(f"Test Macro AUC (OvR): {macro_auc:.4f}")
print(f"Test Cohen's Kappa: {kappa:.4f}")
print("Classification Report:\n", report)
# Out:
# Test Accuracy: 0.5636
# Test Weighted F1: 0.5637
# Test Macro AUC (OvR): 0.9563
# Test Cohen's Kappa: 0.5465
# Classification Report:
#                              precision    recall  f1-score   support
#
#            Apple Scab Leaf       0.67      0.60      0.63        10
#                 Apple leaf       0.47      1.00      0.64         9
#            Apple rust leaf       0.64      0.70      0.67        10
#           Bell_pepper leaf       0.60      0.38      0.46         8
#      Bell_pepper leaf spot       0.45      0.56      0.50         9
#             Blueberry leaf       0.75      0.27      0.40        11
#                Cherry leaf       0.64      0.70      0.67        10
#        Corn Gray leaf spot       0.11      0.25      0.15         4
#           Corn leaf blight       0.62      0.42      0.50        12
#             Corn rust leaf       0.80      0.80      0.80        10
#                 Peach leaf       0.75      0.67      0.71         9
#   Potato leaf early blight       0.33      0.62      0.43         8
#    Potato leaf late blight       0.22      0.25      0.24         8
#             Raspberry leaf       0.86      0.86      0.86         7
#              Soyabean leaf       0.67      0.50      0.57         8
# Squash Powdery mildew leaf       0.83      0.83      0.83         6
#            Strawberry leaf       1.00      1.00      1.00         8
#   Tomato Early blight leaf       0.43      0.33      0.38         9
#  Tomato Septoria leaf spot       0.36      0.45      0.40        11
#                Tomato leaf       0.67      0.50      0.57         8
# Tomato leaf bacterial spot       0.00      0.00      0.00         9
#    Tomato leaf late blight       0.55      0.60      0.57        10
#   Tomato leaf mosaic virus       1.00      0.20      0.33        10
#   Tomato leaf yellow virus       1.00      0.83      0.91         6
#           Tomato mold leaf       0.18      0.33      0.24         6
#                 grape leaf       0.91      0.83      0.87        12
#       grape leaf black rot       0.86      0.75      0.80         8
#
#                   accuracy                           0.56       236
#                  macro avg       0.61      0.56      0.56       236
#               weighted avg       0.62      0.56      0.56       236

# %%
# Step 8 — Post-Training Quantization & Evaluation

# 1. Save the trained FP32 model
model.save("xception_final.keras")

# 2. Convert FP32 → INT8 TFLite model
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]   # enables INT8 quantization
tflite_model_int8 = converter.convert()

# Save INT8 model
with open("xception_int8.tflite", "wb") as f:
    f.write(tflite_model_int8)

print("INT8 quantized model saved as xception_int8.tflite")

# 3. Run inference on test dataset with INT8 model
interpreter = tf.lite.Interpreter(model_path="xception_int8.tflite")
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

y_pred_int8 = []
for i in range(len(X_test)):
    img = np.expand_dims(X_test[i], axis=0).astype(np.float32)  # keep float32 input
    interpreter.set_tensor(input_details[0]['index'], img)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details[0]['index'])
    y_pred_int8.append(np.argmax(output))

y_pred_int8 = np.array(y_pred_int8)

# 4. Evaluate metrics on INT8 model
acc_int8 = accuracy_score(y_test, y_pred_int8)
f1w_int8 = f1_score(y_test, y_pred_int8, average='weighted')
kappa_int8 = cohen_kappa_score(y_test, y_pred_int8)

print("\n INT8 Quantized Model Evaluation:")
print(f"Test Accuracy (INT8): {acc_int8:.4f}")
print(f"Test Weighted F1 (INT8): {f1w_int8:.4f}")
print(f"Test Cohen's Kappa (INT8): {kappa_int8:.4f}")
# Out:
# Saved artifact at '/tmp/tmpeehbb6f1'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 27), dtype=tf.float32, name=None)
# Captures:
#   132395646052560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646051792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646053328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646050640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646055248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646052368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646053712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646054864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646048720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646050448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646056016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646057552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646057936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646054288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646052944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646046992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646058320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646054480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646058128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646051984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646047184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646057168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646057744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646056400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646056784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646051408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646056208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646057360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646055440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646055056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646054672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646055632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646053520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646052176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646052752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646050256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646046608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646046800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646055824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646051600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646056976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646056592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646054096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646049296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646047376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646048528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646048144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646047760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646053904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646042768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646042960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646046032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646050064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646051216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646044880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646049680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646046416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644667088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644667472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646053136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395646048912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644666512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644668432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644668624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644669584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644666896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644669008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644668816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644670160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644670352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644670544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644669776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644670928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644670736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644671312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644671504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644671696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644669968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644672080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644671888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644672464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644672656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644672848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644671120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644673232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644673040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644673616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644673808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644674000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644672272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644674384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644674192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644674768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644674960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644675152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644673424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644675536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644675344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644675920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644676112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644676304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644674576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644676688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644676496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644677072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644677264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644677456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644675728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644677840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644677648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644678224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644678416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644678608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644676880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644678992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644678800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644679376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644679568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644679760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644678032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644680144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644679952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644680528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644680720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644680912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644679184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644681296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644681104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644681680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644666320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644682064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644667280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644680336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644667856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644681872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592024912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592025104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644681488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395644667664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592025296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592025872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592026064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592026256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592025488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592026640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592026448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592027024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592027216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592027408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592025680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592027792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592027600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592028176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592028368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592028560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592026832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592028944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592028752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592029328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592029520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592029712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592027984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592030096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592029904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592030480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592030672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592030864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592029136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592031248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592031056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592031632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592031824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592032016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592030288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592032400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592032208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592032784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592032976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592033168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592031440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592033552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592033360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592033936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592034128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592034320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592032592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592034704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592034512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592035088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592035280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592035472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592033744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592035856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592035664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592036240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592036432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592036624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592034896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592037008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592036816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592037392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592037584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592037776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592036048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592038160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592037968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592038544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592038736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592038928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592037200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592039312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592039120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592039696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592024144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592039888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592039504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592024720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592024336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592040272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592024528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592040080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395592038352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395590730000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395590730192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395590731344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395590731536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395590729808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395590731920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395590731728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395590732304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395590732496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395590732688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395590730768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395590733072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395590733456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395590730960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395590733648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395590734608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395590734416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395590733840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395590734992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132395590734800: TensorSpec(shape=(), dtype=tf.resource, name=None)
# INT8 quantized model saved as xception_int8.tflite
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
#  INT8 Quantized Model Evaluation:
# Test Accuracy (INT8): 0.5551
# Test Weighted F1 (INT8): 0.5534
# Test Cohen's Kappa (INT8): 0.5378

# %%
import os
from tensorflow import keras

# Load model
model_path = "/content/drive/MyDrive/Xceptionfinetune3/best_finetune.keras"
model = keras.models.load_model(model_path)

# Show layer-wise summary
model.summary()

# Show file size
file_size = os.path.getsize(model_path) / (1024 * 1024)  # in MB
print(f"\nModel file size on disk: {file_size:.2f} MB")
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 299, 299, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ augment (Sequential)            │ (None, 299, 299, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception (Functional)           │ (None, 10, 10, 2048)   │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 27)             │        13,851 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 51,618,955 (196.91 MB)
#  Trainable params: 14,846,243 (56.63 MB)
#  Non-trainable params: 7,080,224 (27.01 MB)
#  Optimizer params: 29,692,488 (113.27 MB)
# Model file size on disk: 197.46 MB

# %%
import tensorflow as tf

# 1. Load your trained model
model = tf.keras.models.load_model("/content/drive/MyDrive/Xceptionfinetune3/best_finetune.keras")

# 2. Convert to INT8 TFLite model
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]   # enables INT8 quantization
tflite_model_int8 = converter.convert()

# 3. Save to Google Drive
save_path = "/content/drive/MyDrive/Xceptionfinetune3/xception_int8.tflite"
with open(save_path, "wb") as f:
    f.write(tflite_model_int8)

print(f"✅ INT8 quantized model saved at: {save_path}")
# Out:
# Saved artifact at '/tmp/tmpysvabc72'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 27), dtype=tf.float32, name=None)
# Captures:
#   133851124417168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124423888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124423696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124423312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124424464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124423120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124424080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124424272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124417360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124425424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124424848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124425808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124426000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124426192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124423504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124426576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124426384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124426960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124427536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124427152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124427344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124425616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124427728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124425040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124425232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124422928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124428688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124428112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124429072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124429264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124429456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124424656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124429840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124429648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124430224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124430800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124430416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124430608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124428880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124430992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124428304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124428496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124426768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124431952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124431376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124432336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124431568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124432720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124431760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124427920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124431184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124432528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123729616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123728848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123729808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124432144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851124430032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123728656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123728464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123729040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123730768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123730192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123731152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123731344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123731536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123729232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123731920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123731728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123732304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123732496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123732688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123730960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123733072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123732880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123733456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123733648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123733840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123732112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123734224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123734032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123734608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123734800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123734992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123733264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123735376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123735184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123735760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123735952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123736144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123734416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123736528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123736336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123736912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123737104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123737296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123735568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123737680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123737488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123738064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123738256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123738448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123736720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123738832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123738640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123739216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123739408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123739600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123737872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123739984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123739792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123740368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123740560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123740752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123739024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123741136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123740944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123741520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123741712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123741904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123740176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123742288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123742096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123742672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123742864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123743056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123741328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123743440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123743248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123743824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123744016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123744400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123742480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123744592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123744208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123730000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123729424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123743632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123730576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851123730384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122450704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122450896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122452048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122452240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122450512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122452624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122452432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122453008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122453200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122453392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122451472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122453776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122453584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122454160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122454352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122454544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122452816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122454928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122454736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122455312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122455504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122455696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122453968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122456080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122455888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122456464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122456656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122456848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122455120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122457232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122457040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122457616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122457808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122458000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122456272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122458384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122458192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122458768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122458960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122459152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122457424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122459536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122459344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122459920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122460112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122460304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122458576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122460688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122460496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122461072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122461264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122461456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122459728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122461840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122461648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122462224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122462416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122462608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122460880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122462992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122462800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122463376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122463568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122463760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122462032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122464144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122463952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122464528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122464720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122464912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122463184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122465296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122465104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122465680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122466256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122465872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122466064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122464336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122466448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122465488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122451664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122451856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122451280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122451088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851122466640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851121190096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851121190288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851121189520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851121190672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851121188944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851121191056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851121191248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851121191440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851121190480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851121191824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851121192208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851121189712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851121192400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851121193360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851121193168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851121192592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851121193744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133851121193552: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ INT8 quantized model saved at: /content/drive/MyDrive/Xceptionfinetune3/xception_int8.tflite

# %%
import tensorflow as tf
import numpy as np
import os

def tflite_model_summary(model_path):
    interpreter = tf.lite.Interpreter(model_path=model_path)
    interpreter.allocate_tensors()

    tensor_details = interpreter.get_tensor_details()
    total_params = 0
    total_bytes = 0

    for d in tensor_details:
        shape = d['shape']
        dtype = np.dtype(d['dtype'])
        num_params = np.prod(shape)
        total_params += num_params
        total_bytes += num_params * dtype.itemsize

    print("\n=== Quantized TFLite Model Summary ===")
    print(f"Total params: {total_params:,}")
    print(f"Model size on disk: {os.path.getsize(model_path)/1024/1024:.2f} MB")
    print(f"In-memory param size: {total_bytes/1024/1024:.2f} MB")
    print("Trainable params: 0 (TFLite models are frozen for inference)")
    print("Non-trainable params: all")
    print("Optimizer params: 0 (not stored in TFLite)")

# Example usage
tflite_model_summary("/content/drive/MyDrive/Xceptionfinetune3/xception_int8.tflite")
# Out:
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# === Quantized TFLite Model Summary ===
# Total params: 79,599,384
# Model size on disk: 21.55 MB
# In-memory param size: 203.17 MB
# Trainable params: 0 (TFLite models are frozen for inference)
# Non-trainable params: all
# Optimizer params: 0 (not stored in TFLite)

# %%
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, cohen_kappa_score
import tensorflow as tf

# Load INT8 quantized model
interpreter = tf.lite.Interpreter(model_path="/content/drive/MyDrive/Xceptionfinetune3/xception_int8.tflite")
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Run inference
y_pred_int8 = []
for i in range(len(X_test)):
    img = np.expand_dims(X_test[i], axis=0).astype(np.float32)  # keep float32 input
    interpreter.set_tensor(input_details[0]['index'], img)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details[0]['index'])
    y_pred_int8.append(np.argmax(output))

y_pred_int8 = np.array(y_pred_int8)

# Evaluate metrics
acc_int8 = accuracy_score(y_test, y_pred_int8)
f1w_int8 = f1_score(y_test, y_pred_int8, average='weighted')
kappa_int8 = cohen_kappa_score(y_test, y_pred_int8)

print("\n📊 INT8 Quantized Model Evaluation:")
print(f"Test Accuracy: {acc_int8:.4f}")
print(f"Weighted F1: {f1w_int8:.4f}")
print(f"Cohen's Kappa: {kappa_int8:.4f}")
# Out:
# 📊 INT8 Quantized Model Evaluation:
# Test Accuracy: 0.5720
# Weighted F1: 0.5713
# Cohen's Kappa: 0.5555

# %%
# Step 9 — Confusion Matrix & Per-class PRF

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]  # normalize per row

plt.figure(figsize=(12, 10))
sns.heatmap(cm_norm, annot=True, fmt=".2f", cmap="Blues",
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Normalized Confusion Matrix")
plt.show()

# Per-class Precision, Recall, F1
prf = precision_recall_fscore_support(y_true, y_pred, labels=np.arange(num_classes))
for i, cls in enumerate(class_names):
    print(f"{cls:25s} | "
          f"Precision: {prf[0][i]:.3f}, "
          f"Recall: {prf[1][i]:.3f}, "
          f"F1: {prf[2][i]:.3f}, "
          f"Support: {prf[3][i]}")
# Out:
# Apple Scab Leaf           | Precision: 0.667, Recall: 0.600, F1: 0.632, Support: 10
# Apple leaf                | Precision: 0.474, Recall: 1.000, F1: 0.643, Support: 9
# Apple rust leaf           | Precision: 0.636, Recall: 0.700, F1: 0.667, Support: 10
# Bell_pepper leaf          | Precision: 0.600, Recall: 0.375, F1: 0.462, Support: 8
# Bell_pepper leaf spot     | Precision: 0.455, Recall: 0.556, F1: 0.500, Support: 9
# Blueberry leaf            | Precision: 0.750, Recall: 0.273, F1: 0.400, Support: 11
# Cherry leaf               | Precision: 0.636, Recall: 0.700, F1: 0.667, Support: 10
# Corn Gray leaf spot       | Precision: 0.111, Recall: 0.250, F1: 0.154, Support: 4
# Corn leaf blight          | Precision: 0.625, Recall: 0.417, F1: 0.500, Support: 12
# Corn rust leaf            | Precision: 0.800, Recall: 0.800, F1: 0.800, Support: 10
# Peach leaf                | Precision: 0.750, Recall: 0.667, F1: 0.706, Support: 9
# Potato leaf early blight  | Precision: 0.333, Recall: 0.625, F1: 0.435, Support: 8
# Potato leaf late blight   | Precision: 0.222, Recall: 0.250, F1: 0.235, Support: 8
# Raspberry leaf            | Precision: 0.857, Recall: 0.857, F1: 0.857, Support: 7
# Soyabean leaf             | Precision: 0.667, Recall: 0.500, F1: 0.571, Support: 8
# Squash Powdery mildew leaf | Precision: 0.833, Recall: 0.833, F1: 0.833, Support: 6
# Strawberry leaf           | Precision: 1.000, Recall: 1.000, F1: 1.000, Support: 8
# Tomato Early blight leaf  | Precision: 0.429, Recall: 0.333, F1: 0.375, Support: 9
# Tomato Septoria leaf spot | Precision: 0.357, Recall: 0.455, F1: 0.400, Support: 11
# Tomato leaf               | Precision: 0.667, Recall: 0.500, F1: 0.571, Support: 8
# Tomato leaf bacterial spot | Precision: 0.000, Recall: 0.000, F1: 0.000, Support: 9
# Tomato leaf late blight   | Precision: 0.545, Recall: 0.600, F1: 0.571, Support: 10
# Tomato leaf mosaic virus  | Precision: 1.000, Recall: 0.200, F1: 0.333, Support: 10
# Tomato leaf yellow virus  | Precision: 1.000, Recall: 0.833, F1: 0.909, Support: 6
# Tomato mold leaf          | Precision: 0.182, Recall: 0.333, F1: 0.235, Support: 6
# grape leaf                | Precision: 0.909, Recall: 0.833, F1: 0.870, Support: 12
# grape leaf black rot      | Precision: 0.857, Recall: 0.750, F1: 0.800, Support: 8

# %%
import tensorflow as tf
import os
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, cohen_kappa_score

# 1. Load trained model
model = tf.keras.models.load_model("/content/drive/MyDrive/Xceptionfinetune3/best_finetune.keras")

# 2. Convert to FP32 TFLite (no quantization)
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model_fp32 = converter.convert()

fp32_path = "/content/drive/MyDrive/Xceptionfinetune3/xception_fp32.tflite"
with open(fp32_path, "wb") as f:
    f.write(tflite_model_fp32)

print("✅ FP32 TFLite model saved as:", fp32_path)

# 3. Model size on disk
size_mb = os.path.getsize(fp32_path) / (1024 * 1024)
print(f"📦 FP32 TFLite model size: {size_mb:.2f} MB")

# 4. Evaluate FP32 TFLite model on test set
interpreter = tf.lite.Interpreter(model_path=fp32_path)
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

y_pred_fp32 = []
for i in range(len(X_test)):
    img = np.expand_dims(X_test[i], axis=0).astype(np.float32)  # input must be float32
    interpreter.set_tensor(input_details[0]['index'], img)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details[0]['index'])
    y_pred_fp32.append(np.argmax(output))

y_pred_fp32 = np.array(y_pred_fp32)

acc_fp32 = accuracy_score(y_test, y_pred_fp32)
f1w_fp32 = f1_score(y_test, y_pred_fp32, average='weighted')
kappa_fp32 = cohen_kappa_score(y_test, y_pred_fp32)

print("\n📊 FP32 TFLite Model Evaluation:")
print(f"Test Accuracy: {acc_fp32:.4f}")
print(f"Weighted F1: {f1w_fp32:.4f}")
print(f"Cohen's Kappa: {kappa_fp32:.4f}")

# 5. "Summary" equivalent for TFLite (params size only)
num_params = np.sum([np.prod(v.shape) for v in model.weights])
mem_size_mb = num_params * 4 / (1024*1024)  # FP32 = 4 bytes
print(f"\n📝 Approximate Model Summary after FP32 Quantization:")
print(f"Total params: {num_params:,}")
print(f"In-memory size (FP32): {mem_size_mb:.2f} MB")
print(f"Trainable params: 0 (TFLite models are frozen for inference)")
print(f"Non-trainable params: all")
print(f"Optimizer params: 0")
# Out:
# Saved artifact at '/tmp/tmpeayqvif1'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 27), dtype=tf.float32, name=None)
# Captures:
#   138245838556432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838558544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838559312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838557968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838557008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838558352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838558928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838558736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838558160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838560272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838559696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838560656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838561040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838561616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838560080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838556816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838561424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838562000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838562960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838562576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838562768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838559120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838563152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838564304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838564496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838563728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838560848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838563344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838561808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838565264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838565456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838564112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838565840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838565648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838564688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838566992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838566608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838566800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838562384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838567184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838566416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838565072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838563920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838568144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838567568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838568528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838568720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838569104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838566032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838569296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838568912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838562192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826969872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838567376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838568336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838567952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245838567760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826971024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826970832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826970448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826971600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826970064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826971984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826972176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826972368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826970256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826972752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826972560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826973136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826973328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826973520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826971792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826973904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826973712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826974288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826974480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826974672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826972944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826975056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826974864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826975440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826975632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826975824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826974096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826976208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826976016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826976592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826976784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826976976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826975248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826977360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826977168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826977744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826977936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826978128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826976400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826978512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826978320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826978896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826979088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826979280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826977552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826979664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826979472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826980048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826980240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826980432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826978704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826980816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826980624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826981200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826981392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826981584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826979856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826981968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826981776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826982352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826982544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826982736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826981008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826983120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826982928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826983504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826983696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826983888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826982160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826984272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826984080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826984656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826984848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826985040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826983312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826985424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826985232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826985808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826970640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826971216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826971408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826985616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826984464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826969680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825594960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825595152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825594384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825593808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825593616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825595536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825595728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825595920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825593424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825596304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825596112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825596688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825596880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825597072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825595344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825597456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825597264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825597840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825598032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825598224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825596496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825598608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825598416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825598992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825599184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825599376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825597648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825599760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825599568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825600144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825600336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825600528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825598800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825600912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825600720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825601296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825601488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825601680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825599952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825602064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825601872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825602448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825602640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825602832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825601104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825603216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825603024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825603600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825603792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825603984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825602256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825604368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825604176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825604752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825604944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825605136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825603408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825605520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825605328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825605904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825606096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825606288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825604560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825606672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825606480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825607056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825607248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825607440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825605712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825607824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825607632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825608208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825608784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825608400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825608592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825606864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825608976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825594768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825609168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825609552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825594000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825608016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825594576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826364624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826364816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825609360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245825594192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826363472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826365200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826365392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826365584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826363664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826365968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826366352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826364432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826366544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826367504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826367312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826366736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826367888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826367696: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ FP32 TFLite model saved as: /content/drive/MyDrive/Xceptionfinetune3/xception_fp32.tflite
# 📦 FP32 TFLite model size: 83.38 MB
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# 📊 FP32 TFLite Model Evaluation:
# Test Accuracy: 0.5678
# Weighted F1: 0.5725
# Cohen's Kappa: 0.5510
#
# 📝 Approximate Model Summary after FP32 Quantization:
# Total params: 21,926,467
# In-memory size (FP32): 83.64 MB
# Trainable params: 0 (TFLite models are frozen for inference)
# Non-trainable params: all
# Optimizer params: 0

# %%
import os
import tensorflow as tf
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, cohen_kappa_score

# Paths
orig_model_path = "/content/drive/MyDrive/Xceptionfinetune3/best_finetune.keras"
fp32_path = "/content/drive/MyDrive/Xceptionfinetune3/xception_fp32.tflite"

# ✅ Check if file exists and get size
if os.path.exists(orig_model_path):
    orig_size_mb = os.path.getsize(orig_model_path) / (1024 * 1024)
    print(f"📦 Original Keras model size: {orig_size_mb:.2f} MB")
else:
    print("⚠️ Original Keras model not found at:", orig_model_path)

# Load trained model
model = tf.keras.models.load_model(orig_model_path)

# Convert to FP32 TFLite (no quantization)
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model_fp32 = converter.convert()

# Save directly to Google Drive
with open(fp32_path, "wb") as f:
    f.write(tflite_model_fp32)

print("✅ FP32 TFLite model saved at:", fp32_path)

# ✅ FP32 TFLite model size
fp32_size_mb = os.path.getsize(fp32_path) / (1024 * 1024)
print(f"📦 FP32 TFLite model size: {fp32_size_mb:.2f} MB")

# Evaluate FP32 TFLite model
interpreter = tf.lite.Interpreter(model_path=fp32_path)
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

y_pred_fp32 = []
for i in range(len(X_test)):
    img = np.expand_dims(X_test[i], axis=0).astype(np.float32)
    interpreter.set_tensor(input_details[0]['index'], img)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details[0]['index'])
    y_pred_fp32.append(np.argmax(output))

y_pred_fp32 = np.array(y_pred_fp32)

acc_fp32 = accuracy_score(y_test, y_pred_fp32)
f1w_fp32 = f1_score(y_test, y_pred_fp32, average='weighted')
kappa_fp32 = cohen_kappa_score(y_test, y_pred_fp32)

print("\n📊 FP32 TFLite Model Evaluation:")
print(f"Test Accuracy: {acc_fp32:.4f}")
print(f"Weighted F1: {f1w_fp32:.4f}")
print(f"Cohen's Kappa: {kappa_fp32:.4f}")

# Model param summary
num_params = np.sum([np.prod(v.shape) for v in model.weights])
mem_size_mb = num_params * 4 / (1024*1024)
print(f"\n📝 Approximate Model Summary after FP32 Quantization:")
print(f"Total params: {num_params:,}")
print(f"In-memory size (FP32): {mem_size_mb:.2f} MB")
print("Trainable params: 0 (TFLite models are frozen for inference)")
print("Non-trainable params: all")
print("Optimizer params: 0")
# Out:
# 📦 Original Keras model size: 197.46 MB
# Saved artifact at '/tmp/tmpv2vxr_p3'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 27), dtype=tf.float32, name=None)
# Captures:
#   138245826935888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826934544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826934736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826935120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826933968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826935312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826934352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826934160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826935504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826933200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826933584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826933776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826933392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826934928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826933008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826932816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245826935696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324477904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324479248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324478864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324479056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324478480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324479440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324477712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324477520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324478672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324480400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324479824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324480784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324480976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324481168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324478096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324481552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324481360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324481936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324482512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324482128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324482320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324480592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324482704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324480016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324480208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324478288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324483664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324483088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324484048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324484240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324484432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324479632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324484816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324484624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324485200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324485776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324485392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324485584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324483856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324485968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324483280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324483472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324481744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324486928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324486352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324487312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324487504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324487696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324482896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324488080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324487888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324488464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324488656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324488848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324487120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324489232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324489040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324489616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324489808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324490000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324488272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324490384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324490192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324490768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324490960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324491152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324489424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324491536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324491344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324491920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324492112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324492304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324490576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324492688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324492496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324493072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324493264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324492880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324486736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324486160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324485008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324491728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324493648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828658384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324486544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243324493456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828657424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828658768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828658960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828659152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828657232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828659536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828659344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828659920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828660112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828660304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828658576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828660688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828660496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828661072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828661264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828661456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828659728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828661840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828661648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828662224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828662416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828662608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828660880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828662992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828662800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828663376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828663568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828663760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828662032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828664144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828663952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828664528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828664720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828664912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828663184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828665296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828665104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828665680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828665872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828666064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828664336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828666448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828666256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828666832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828667024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828667216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828665488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828667600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828667408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828667984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828668176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828668368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828666640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828668752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828668560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828669136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828669328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828669520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828667792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828669904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828669712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828670288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828670480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828670672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828668944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828671056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828670864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828671440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828671632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828671824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828670096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828672208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828672016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828672592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828672784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828673168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828671248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828673360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828672976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828658192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828657616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828672400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828658000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138245828657808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084026128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084026320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084027472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084027664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084025936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084028048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084027856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084028432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084028624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084028816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084026896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084029200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084029008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084029584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084029776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084029968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084028240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084030352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084030160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084030736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084030928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084031120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084029392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084031504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084031312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084031888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084032464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084032080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084032272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084030544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084032656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084027280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084027088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084026512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084033616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084033040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084034000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084034192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084034384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084026704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084034768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084034576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084035152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084035344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084035536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084033808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084035920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084036304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084033424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084036496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084037456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084037264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084036688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084037840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138243084037648: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ FP32 TFLite model saved at: /content/drive/MyDrive/Xceptionfinetune3/xception_fp32.tflite
# 📦 FP32 TFLite model size: 83.38 MB
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# 📊 FP32 TFLite Model Evaluation:
# Test Accuracy: 0.5678
# Weighted F1: 0.5725
# Cohen's Kappa: 0.5510
#
# 📝 Approximate Model Summary after FP32 Quantization:
# Total params: 21,926,467
# In-memory size (FP32): 83.64 MB
# Trainable params: 0 (TFLite models are frozen for inference)
# Non-trainable params: all
# Optimizer params: 0

# %%
import os

# Paths
orig_model_path = "/content/drive/MyDrive/Xceptionfinetune3/best_finetune.keras"
fp32_tflite_path = "/content/drive/MyDrive/Xceptionfinetune3/xception_fp32.tflite"

# Function to print model size
def print_model_size(path, name):
    if os.path.exists(path):
        size_mb = os.path.getsize(path) / (1024 * 1024)
        print(f"📦 {name} size on disk: {size_mb:.2f} MB")
    else:
        print(f"⚠️ {name} not found at {path}")

# Print sizes
print_model_size(orig_model_path, "Original Keras model")
print_model_size(fp32_tflite_path, "FP32 TFLite model")
# Out:
# 📦 Original Keras model size on disk: 197.46 MB
# 📦 FP32 TFLite model size on disk: 83.38 MB
